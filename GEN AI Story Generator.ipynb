# %%
from openai import OpenAI
from transformers import pipeline

# %% [markdown]
# ## Gen AI Text Generation on Artificial Intelligence

# %%
import os
import warnings

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
warnings.filterwarnings("ignore")

from transformers.utils import logging
logging.set_verbosity_error()

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Artificial Intelligence is",
    max_length=100,
    pad_token_id=50256
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Artificial Intelligence is a subject that has been hotly debated. The idea that artificial intelligence could be used to train a wide variety of human scientists comes from the notion that humans have become more mature since childhood, and that we are naturally, socially and mentally more capable.
#
# But some of the scientists who have proposed artificial intelligence for the next decade are working on computer models that are capable of producing intelligent behavior. These models are based on the theory that humans, like any other species, have evolved over millions of years. In the case of humans, it's because the human brain is designed to be able to process information quickly, and it's because humans have evolved to learn quickly from experience.
#
# In the case of the human brain, we have learned a lot over the course of our lives, and we've learned how to think. And so we can do things that humans can't do, or can't do, or can't do. And so in the case of artificial intelligence — this is just an example — it's really important to understand that we have evolved to learn how to think.
#
# I think we're in a very nice position. We're the only species in the universe where we can do things that humans can't do, and we don't have to deal

# %% [markdown]
# ## Gen AI Text Generation on Full Stack Python

# %%
import os
import warnings

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
warnings.filterwarnings("ignore")

from transformers.utils import logging
logging.set_verbosity_error()

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Python is",
    max_length=250,
    temperature=0.9,
    pad_token_id=50256
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Python is a powerful piece of software written in C++11. It allows you to write some really beautiful web apps, with a few tricks and some useful scripts.
#
# You can use it to create your own personal web apps, or to create a group website based around the web.
#
# How do you manage an environment that is not available in the real world?
#
# We provide an alternative to an environment that allows a user to learn what has been built and then have to design more complex applications that can be run under different environments.
#
# For example, we can set up custom themes and web widgets, but we can do it using a new version of Visual Studio. If you use this in order to keep things simple, you might run into bugs in the new version, so you will have to switch to the old version.
#
# How do you ensure that the content of your web app is fully readable?
#
# We are using Visual Studio 2017, which is a language that's been in development for a few years. It's still in its infancy, so there's a lot of work here but it's still a good tool for working with code.
#
# So, how do you ensure that you have the right tools?
#
# The best way to

# %% [markdown]
# ## Gen AI Text Generation on SAP

# %%
import os
import warnings

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
warnings.filterwarnings("ignore")

from transformers.utils import logging
logging.set_verbosity_error()

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "SAP is",
    max_length=100,
    pad_token_id=50256
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# SAP is now in its 12th year of operation.
#
# In its last six months, AP has received more than 2,200 calls from people wanting to learn more about the company's new policy, which is aimed at encouraging them to become more involved in the movement.
#
# For the past few months, AP has been working with the American Association of Chief Financial Officers (AACC), a group of about 200 financial institutions, to prepare a letter to the Federal Reserve asking it to take its advice "to make sure that AP is aware of the policy and practices that are being used by the New York Fed to manipulate or disrupt its regulatory efforts."
#
# AP's role in the movement to prevent the Fed from rigging its own balance sheet is unclear at this time.

# %% [markdown]
# ## Gen AI Text Generation on Data Science

# %%
import os
import warnings

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
warnings.filterwarnings("ignore")

from transformers.utils import logging
logging.set_verbosity_error()

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Data Science is",
    max_length=100,
    pad_token_id=50256
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Data Science is an independent research and teaching organization dedicated to understanding how science works, how research is conducted, and how it impacts society. Our mission is to inspire and empower our students and colleagues to take active part in research and to engage in important conversations about the science of science.
#
# Read more about the National Science Foundation (NSF)
#
# For more information, visit http://www.nsf.gov/
#
# For more information on the Federal Science Foundation (FSF), visit http://www.fstf.gov/about.
#
# For more information on science education, visit: http://www.fstf.gov/about/about

# %% [markdown]
# ## Gen AI Text Generation on Data Analytics

# %%
import os
import warnings

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
warnings.filterwarnings("ignore")

from transformers.utils import logging
logging.set_verbosity_error()

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Data Analytics is",
    max_length=100,
    pad_token_id=50256
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Data Analytics is an independent data analytics company based in Seattle. We have a focus on providing an effective customer service experience and provide all aspects of our business to our customers.
